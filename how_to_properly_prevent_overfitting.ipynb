# %% [markdown]
# ## Imports

# %%
# DATA MANIPULATION
import numpy as np

# DATA VISUALIZATION
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import StandardScaler

# BLOB DATASET
from sklearn.datasets import make_blobs

# KERAS
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # How to Properly Prevent Overfitting

# %% [markdown]
# 🎯 **Goals of this challenge**
# - **`Cross Validate`** a Deep Learning Model
# - Give a **`Validation Set`** to the model
# - Apply two techniques to prevent overfitting:
#     - Use the **`Early Stopping`** criterion to prevent the Neural network from over-learning / over-fitting
#     - **`Regularize`** your network
# - Analyze the **`impact of the batch size and the number of epochs`** on the training of a Neural Network

# %% [markdown]
# ## Data - the `blobs` Dataset

# %% [markdown]
# ### Generating a Blobs Dataset
#
# First, let's generate some data using the [`make_blobs`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html) function from Scikit-Learn
#
# Generate 2000 samples with 10 features each; there should be 8 classes of blobs (`centers` argument) with `cluster_std` equal to 7.

# %%
# YOUR CODE HERE
X, y = make_blobs(n_samples=2000, n_features=10, centers=8, cluster_std=7)

# %% [markdown]
# ### Visualizing the Dataset
#
# All your samples have 10 features. Plot one of the dimensions against another.

# %%
# YOUR CODE HERE
# Visualizing the Dataset - Plot one dimension against another
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', alpha=0.7)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Visualization of Two Features from the Blobs Dataset')
plt.colorbar(label='Class')
plt.show()

# %% [markdown]
# ### Encoding your Categorical Target
#
# Use the 📚 [**to_categorical()**](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical) function to convert `y` to `y_cat`, which is the categorical representation of `y` with **One-Hot encoded** columns.

# %%
# YOUR CODE HERE
# Encoding your Categorical Target
y_cat = to_categorical(y)

# Print shape to verify
print( y.shape)
print(y_cat.shape)
# Out:
# (2000,)
# (2000, 8)

# %% [markdown]
# ## (1) Cross-Validation in Deep Learning
#
# 👩🏻‍🏫 In a previous challenge, we split the dataset into a training set and a testing set at the beginning of the notebook. Then, we started to build different models which were trained on the training set and evaluated on the testing set.
#
# So, at the end of the day, we used the testing set every time we evaluated our models and different hyperparameters. This is normal: we always train on the training set and we evaluate on the testing set.
#
# However, we selected our "best model" based on the score of each model. In other words, we _used_ the test set to select our best model, which means there was ❗️ `data leakage` ❗️
#
# 🤔 **what should we do?**
#
# - A first good practice is to avoid using `random_state` or any deterministic separation between your training and testing sets. In that case, your testing set will change every time you re-run your notebook. This is far from being sufficient, though
# - To compare models properly, you have to run a cross-validation, a 10-fold split, for instance
#
# 🧐 If you look at [sklearn.model_selection.cross_validate](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html), this Cross -Validation tool is designed for Machine Learning algorithms implemented in Scikit Learn, whereas we have been creating and using Neural Networks from Tensorflow/Keras.
#
# 🔥 Let's discover how to **Cross-validate a Neural Network**.

# %% [markdown]
# ### Designing a Neural Network
#
# First, write a function that generates a Neural Network with 3 layers:
#
# <u>Architecture</u>
# - an **input layer** with 25 neurons, the `relu` activation function and the appropriate `input_dim`
# - a **hidden layer** with 10 neurons and the `relu` activation function.
# - a **predictive layer** that is suited to the problem at hand (*multiclass classification*)
#
# <u>Compilation</u>
#
# The function should include a compilation method with:
# - the *categorical_crossentropy* loss
# - the *Adam* optimizer
# - the *accuracy* metric

# %%
def initialize_model():
    # YOUR CODE HERE
    model = models.Sequential()

    # Input layer
    model.add(layers.Dense(25, activation='relu', input_dim=10))

    # Hidden layer
    model.add(layers.Dense(10, activation='relu'))

    # Predictive layer
    model.add(layers.Dense(8, activation='softmax'))

    # Compile the model
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# ### Cross-Validating the Neural Net
#
# 🧑🏻‍💻 Write a _loop_ using the [K-Fold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) function from Scikit-Learn.
#
# * ✂️ Choose 10 splits to fit your model on the training data
# * 🧪 Evaluate your model on the testing data, and store the results of the evaluation into a `results` variable.
#
# _Hints_:
# * ⚖️ Do not forget to standardize your training data before fitting the NN
# * 👌 150 epochs should be sufficient for a first approximation
# * 🤝 As this is your first Deep Learning Cross-Validation, you are guided; just uncomment the following cell and follow the steps
# * ⏳ Notice that we added `%% time` at the beginning of this Jupyter Notebook cell to display its running time, and we encourage you to do so whenever you run expensive computations

# %%
# %%time

# kf = KFold(n_splits=10)
# kf.get_n_splits(X)

# results = []

# for train_index, test_index in kf.split(X):
#     # Split the data into train and test


#     # Scaling your data


#     # Initialize the model


#     # Fit the model on the train data


#     # Evaluate the model on the test data

import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

# 1. Data Preparation
num_classes = len(np.unique(y))
X_scaled = StandardScaler().fit_transform(X)
y_cat = to_categorical(y, num_classes=num_classes)

# 2. Optimized Model Definition
def create_optimized_model(input_shape, num_classes):
    model = models.Sequential([
        layers.Dense(128, activation='relu', input_shape=input_shape,
                    kernel_regularizer=regularizers.l2(0.01)),
        layers.BatchNormalization(),
        layers.Dropout(0.4),

        layers.Dense(64, activation='relu',
                    kernel_regularizer=regularizers.l2(0.01)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),

        layers.Dense(32, activation='relu'),
        layers.BatchNormalization(),

        layers.Dense(num_classes, activation='softmax')
    ])

    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer,
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model

# 3. Enhanced Training Setup
early_stopping = EarlyStopping(monitor='val_accuracy',
                              patience=15,
                              restore_best_weights=True,
                              mode='max')

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                             factor=0.5,
                             patience=5,
                             min_lr=1e-6)

# 4. Cross-Validation with Tracking
kf = KFold(n_splits=10, shuffle=True, random_state=42)
results = []
histories = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X_scaled)):
    print(f"\nFold {fold + 1}")

    X_train, X_val = X_scaled[train_idx], X_scaled[val_idx]
    y_train, y_val = y_cat[train_idx], y_cat[val_idx]
    es = EarlyStopping(patience=10, restore_best_weights=True, verbose=0)

    model = create_optimized_model((X.shape[1],), num_classes)


    history = model.fit(X_train, y_train,
                       epochs=200,
                       batch_size=64,
                       validation_data=(X_val, y_val),
                       callbacks=[early_stopping, reduce_lr],
                       verbose=1)

    ev = model.evaluate(X_val, y_val, verbose=0)
    results.append(ev)
    histories.append(history)
# Out:
# Fold 1
# Epoch 1/200
# 29/29 [==============================] - 1s 8ms/step - loss: 3.3030 - accuracy: 0.2339 - val_loss: 2.8395 - val_accuracy: 0.5700 - lr: 0.0010
# Epoch 2/200
# 29/29 [==============================] - 0s 5ms/step - loss: 2.3904 - accuracy: 0.5083 - val_loss: 2.5274 - val_accuracy: 0.6750 - lr: 0.0010
# Epoch 3/200
# 29/29 [==============================] - 0s 4ms/step - loss: 2
- val_accuracy: 0.7600 - lr: 0.0010
# Epoch 31/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.8088 - accuracy: 0.8044 - val_loss: 0.8017 - val_accuracy: 0.7700 - lr: 0.0010
# Epoch 32/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7427 - accuracy: 0.8083 - val_loss: 0.7986 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 33/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7369 - accuracy: 0.8083 - val_loss: 0.8016 - val_accuracy: 0.7850 - lr: 0.0010
# Epoch 34/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7771 - accuracy: 0.8006 - val_loss: 0.7881 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 35/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7202 - accuracy: 0.8161 - val_loss: 0.8104 - val_accuracy: 0.7650 - lr: 0.0010
# Epoch 36/200
# 29/29 [==============================] - 0s 5ms/step - loss: 0.7374 - accuracy: 0.7972 - val_loss: 0.7965 - val_accuracy: 0.7700 - lr: 0.0010
# Epoch 37/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7105 - accuracy: 0.8017 - val_loss: 0.7751 - val_accuracy: 0.7700 - lr: 0.0010

# %%
#%%time
#
#kf = KFold(n_splits=10, shuffle=True, random_state=42)
#
#results = []
#
#for train_index, test_index in kf.split(X):
#    # Split the data into train and test
#    X_train, X_test = X[train_index], X[test_index]
#    y_train, y_test = y_cat[train_index], y_cat[test_index]
#
#    # Scale the data using the pre-defined SScaler
#    X_train_scaled = SScaler.fit_transform(X_train)
#    X_test_scaled = SScaler.transform(X_test)
#
#    # Initialize the model
#    model = initialize_model()
#
#    # Add EarlyStopping callback
#    es = EarlyStopping(patience=10, restore_best_weights=True, verbose=0)
#
#    # Fit the model on the train data
#    model.fit(
#        X_train_scaled,
#        y_train,
#        validation_split=0.2,
#        epochs=100,
#        batch_size=32,
#        verbose=0,
#        callbacks=[es]
#    )
#
#    # Evaluate the model on the test data
#    ev = model.evaluate(X_test_scaled, y_test, verbose=0)
#    results.append(ev)
# Out:
# CPU times: user 45.6 s, sys: 16.2 s, total: 1min 1s
# Wall time: 45.7 s

# %%
results
# Out:
# [[1.1107321977615356, 0.8149999976158142],
#  [0.7720731496810913, 0.8100000023841858],
#  [1.0846704244613647, 0.800000011920929],
#  [0.9238812327384949, 0.8600000143051147],
#  [1.2867798805236816, 0.7850000262260437],
#  [0.6911681294441223, 0.8349999785423279],
#  [0.661195695400238, 0.8500000238418579],
#  [1.0170496702194214, 0.7900000214576721],
#  [0.7841843962669373, 0.8299999833106995],
#  [0.9079641103744507, 0.7900000214576721]]

# %% [markdown]
# ### Performance of the Cross-Validated Network
#
# Print the average accuracy of these 10 folds and the standard deviation of these 10 accuracy values.

# %%
accuracy = [_[1] for _ in results]

print(f'New mean accuracy: {np.mean(accuracy)*100:.2f}% (±{np.std(accuracy)*100:.2f})')
# Out:
# New mean accuracy: 81.65% (±2.50)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### Remarks About the Computational Time
#
# - 🤯 You probably encountered one of the main drawbacks of using proper cross-validation for a Neural Network: **it takes a lot of time**! Therefore, for the rest of the Deep-Learning module, we will do **only one fold**
# - 👮🏻‍♀️ Remember that this is not entirely correct and, for real-life applications and problems, you are encouraged to use a proper cross-validation technique
# - 💼 In general, people split only once, as you did. Once they get to the end of their optimization, they launch a real cross-validation run at 6 PM, go home and get the final results on the next day

# %% [markdown]
# ### Holdout Method
#
# For the rest of the exercise (and of the Deep Learning module), split the dataset into a training set and a testing set with a 70/30% training-to-test data ratio.
#
# Make sure to also scale the data after splitting!

# %%
# YOUR CODE HERE
# YOUR CODE HERE
X_train, X_test, y_train, y_test = train_test_split(X, y_cat, test_size=0.3, random_state=42)

# %%
# Scale the data
SScaler = StandardScaler()
SScaler.fit(X_train)

X_train_scaled = SScaler.transform(X_train)
X_test_scaled = SScaler.transform(X_test)

# %% [markdown]
# ## (2) How to Prevent a Neural Network from Overfitting?

# %% [markdown]
# ### (2.1) Early Stopping
#
# 🚦 **Stop the learning process before overfitting**

# %% [markdown]
# #### Illustrating How a Neural Network Easily Overfits
#
# First things first, let's show that if we train the model for too long (= for too many epochs) it will overfit the training data and will not be good at predicting the testing data.
#
# **How can we do it without using the testing data, which is strictly forbidden?**
#
# You can use a fraction of the <font color=blue>training set</font> as a <font color=green>validation set</font>.
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/lectures/deep-learning/02/validation_set.png" width=450>
#
# With Keras, you don't have to re-use the `train_test_split` method from Scikit-Learn. Instead, you have two options:
#
# - `validation_split = 0.2` (for example): the last 20% of the observations in the training set will be used as the validation holdout set.
# - `validation_data = (X_val, y_val)` if you have access to a dataset that you want to use as the validation holdout set.
#
# 👉 Let's go with the first option and set `epochs = 500`.
#
# 👉 Store the performances of the model in a `history` variable.

# %%
# %%time
# YOUR CODE HERE
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=500,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.1078 - accuracy: 0.6987 - val_loss: 0.8409 - val_accuracy: 0.8029
# Epoch 2/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.0497 - accuracy: 0.7283 - val_loss: 0.8517 - val_accuracy: 0.7862
# Epoch 3/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.0362 - accuracy: 0.7191 - val_loss: 0.8582 - val_accuracy: 0.7743
# Epoch 4/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.0195 - accuracy: 0.7406 - val_loss: 0.8538 - val_accuracy: 0.7648
# Epoch 5/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.9217 - accuracy: 0.7681 - val_loss: 0.8522 - val_accuracy: 0.7601
# Epoch 6/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.9524 - accuracy: 0.7528 - val_loss: 0.8482 - val_accuracy: 0.7672
# Epoch 7/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.8965 - accuracy: 0.7620 - val_loss: 0.8508 - val_accuracy: 0.7553
# Epoch 8/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.9559 - accuracy: 0.7446 - val_loss: 0.8187 - val_accuracy: 0.7767
# Epoch 9/500
# 62/62 [==============================] - 1s 24ms/step - loss: 0.8654 - accuracy: 0.7865 - val_loss: 0.8107 - val_accuracy: 0.7648
# Epoch 10/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.8577 - accuracy: 0.7763 - val_loss: 0.8130 - val_accuracy: 0.7577
# Epoch 11/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.8294 - accuracy: 0.7763 - val_loss: 0.7847 - val_accuracy: 0.7696
# Epoch 12/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.8610 - accuracy: 0.7753 - val_loss: 0.8006 - val_accuracy: 0.7530
# Epoch 13/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.8805 - accuracy: 0.7651 - val_loss: 0.8102 - val_accuracy: 0.7553
# Epoch 14/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.8773 - accuracy: 0.7600 - val_loss: 0.8028 - val_accuracy: 0.7553
# Epoch 15/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.8021 - accuracy: 0.7804 - val_loss: 0.7861 - val_accuracy: 0.7648
# Epoch 16/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.8499 - accuracy: 0.7661 - val_loss: 0.7891 - val_accuracy: 0.7482
# Epoch 17/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.8298 - accuracy: 0.7722 - val_loss: 0.8157 - val_accuracy: 0.7577
# Epoch 18/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.8424 - accuracy: 0.7610 - val_loss: 0.7825 - val_accuracy: 0.7577
# Epoch 19/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0
500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6165 - accuracy: 0.8284 - val_loss: 0.8909 - val_accuracy: 0.7363
# Epoch 473/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5931 - accuracy: 0.8345 - val_loss: 0.8762 - val_accuracy: 0.7411
# Epoch 474/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5674 - accuracy: 0.8437 - val_loss: 0.8576 - val_accuracy: 0.7435
# Epoch 475/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5672 - accuracy: 0.8386 - val_loss: 0.8650 - val_accuracy: 0.7553
# Epoch 476/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5643 - accuracy: 0.8478 - val_loss: 0.8682 - val_accuracy: 0.7553
# Epoch 477/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6161 - accuracy: 0.8519 - val_loss: 0.8662 - val_accuracy: 0.7530
# Epoch 478/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5412 - accuracy: 0.8580 - val_loss: 0.8903 - val_accuracy: 0.7458
# Epoch 479/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5709 - accuracy: 0.8488 - val_loss: 0.8995 - val_accuracy: 0.7553
# Epoch 480/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5836 - accuracy: 0.8274 - val_loss: 0.8960 - val_accuracy: 0.7625
# Epoch 481/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5442 - accuracy: 0.8498 - val_loss: 0.8977 - val_accuracy: 0.7553
# Epoch 482/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5628 - accuracy: 0.8498 - val_loss: 0.9313 - val_accuracy: 0.7530
# Epoch 483/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5373 - accuracy: 0.8355 - val_loss: 0.9069 - val_accuracy: 0.7458
# Epoch 484/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5745 - accuracy: 0.8447 - val_loss: 0.9098 - val_accuracy: 0.7553
# Epoch 485/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5826 - accuracy: 0.8427 - val_loss: 0.9113 - val_accuracy: 0.7530
# Epoch 486/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5823 - accuracy: 0.8233 - val_loss: 0.9199 - val_accuracy: 0.7458
# Epoch 487/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5747 - accuracy: 0.8437 - val_loss: 0.8995 - val_accuracy: 0.7435
# Epoch 488/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5361 - accuracy: 0.8621 - val_loss: 0.8995 - val_accuracy: 0.7530
# Epoch 489/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5761 - accuracy: 0.8478 - val_loss: 0.9155 - val_accuracy: 0.7577
# Epoch 490/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5821 - accuracy: 0.8458 - val_loss: 0.9210 - val_accuracy: 0.7482
# Epoch 491/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5729 - accuracy: 0.8427 - val_loss: 0.8714 - val_accuracy: 0.7411
# Epoch 492/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5913 - accuracy: 0.8366 - val_loss: 0.8942 - val_accuracy: 0.7458
# Epoch 493/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5995 - accuracy: 0.8304 - val_loss: 0.9159 - val_accuracy: 0.7387
# Epoch 494/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6148 - accuracy: 0.8315 - val_loss: 0.9025 - val_accuracy: 0.7458
# Epoch 495/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5470 - accuracy: 0.8539 - val_loss: 0.9298 - val_accuracy: 0.7648
# Epoch 496/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6138 - accuracy: 0.8345 - val_loss: 0.9133 - val_accuracy: 0.7530
# Epoch 497/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6266 - accuracy: 0.8396 - val_loss: 0.9590 - val_accuracy: 0.7363
# Epoch 498/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5656 - accuracy: 0.8509 - val_loss: 0.9303 - val_accuracy: 0.7435
# Epoch 499/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5801 - accuracy: 0.8560 - val_loss: 0.9237 - val_accuracy: 0.7482
# Epoch 500/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5997 - accuracy: 0.8376 - val_loss: 0.9158 - val_accuracy: 0.7482
# CPU times: user 2min 44s, sys: 1min 10s, total: 3min 54s
# Wall time: 2min 10s

# %% [markdown]
# #### Your Neural Network's Performance
#
# Evaluate the model on the testing set and print the accuracy.

# %%
# YOUR CODE HERE
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test, verbose=1)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 19/19 [==============================] - 0s 1ms/step - loss: 0.8765 - accuracy: 0.7467
# Test Loss: 0.8765
# Test Accuracy: 0.7467

# %% [markdown]
# #### Learnings About Number of Epochs
#
# Plot the history of the model with the `plot_loss_accuracy()` function that we coded for you.
#
# What do you observe?

# %%
def plot_loss_accuracy(history, title=None):
    fig, ax = plt.subplots(1,2, figsize=(20,7))

    # --- LOSS ---

    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])

    ax[0].set_title('Model loss')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')

    ax[0].set_ylim((0,3))

    ax[0].legend(['Train', 'Test'], loc='best')

    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)

    # --- ACCURACY

    ax[1].plot(history.history['accuracy'])
    ax[1].plot(history.history['val_accuracy'])

    ax[1].set_title('Model Accuracy')
    ax[1].set_ylabel('Accuracy')
    ax[1].set_xlabel('Epoch')

    ax[1].legend(['Train', 'Test'], loc='best')

    ax[1].set_ylim((0,1))

    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)

    if title:
        fig.suptitle(title)

# %%
# YOUR CODE HERE
plot_loss_accuracy(history, title="Model Loss and Accuracy Over Epochs")

# %% [markdown]
# 👩🏻‍🏫 We clearly see that **the number of epochs we choose has a strong influence on the final results**:
#
# **INSUFFICIENT NUMBER OF EPOCHS $\implies$ UNDERFITTING**:
# - The algorithm is not optimal as its Loss Function has **not converged yet**
# - It hasn't learned enough from the training data
#
# **TOO MANY EPOCHS** $\implies$ **OVERFITTING**:
# - Our Neural Network has **learned too much** from the training data, including its noisy information
# - the algorithm **does not generalize well** on test data
#
# 🚦 Basically, what we want to do is stop the algorithm **when the test loss is minimal** (or when the testing metrics are maximal)

# %% [markdown]
# #### Early Stopping
#
# 🧑🏻‍🏫 Let's introduce the **Early Stopping** criterion.
#
# The Early Stopping criterion is a way to **automatically stop the training of the algorithm** before reaching the number of epochs that was originally set.
#
# 🕵🏻‍♂️ **How does it work?**
#
# The model will pay attention to the **<font color=green>loss of the validation set</font>**. If <font color=green>it</font> starts increasing again 📈 while the <font color=blue>loss of the training set</font> keeps decreasing 📉, it is a good sign that the model is overfitting and the training should be stopped!
#
#
# <img src="validation_set.png" alt="Validation set" width=450/>

# %% [markdown]
# ##### Observing the Early Stopping Criterion
#
# Run the following code and plot the history.

# %%
# %%time

es = EarlyStopping()

model = initialize_model()

# Fit the model on the train data
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 500,
    batch_size = 16,
    verbose = 1,
    callbacks = [es] # This will call the Early Stopping Criterion for each epoch
)
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 4ms/step - loss: 2.0878 - accuracy: 0.1655 - val_loss: 1.9639 - val_accuracy: 0.2375
# Epoch 2/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.8980 - accuracy: 0.2697 - val_loss: 1.7800 - val_accuracy: 0.3302
# CPU times: user 819 ms, sys: 249 ms, total: 1.07 s
# Wall time: 811 ms

# %% [markdown]
# ##### Evaluate the ES Model
#
# _(also look at the historical losses)_

# %%
# YOUR CODE HERE
es = EarlyStopping(patience=30, restore_best_weights=True)

model = initialize_model()

# Fit the model on the train data
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=500,
    batch_size=16,
    verbose=1,
    callbacks=[es]
)

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test, verbose=1)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 4ms/step - loss: 2.0953 - accuracy: 0.1502 - val_loss: 1.9613 - val_accuracy: 0.1948
# Epoch 2/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1
500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4435 - accuracy: 0.8417 - val_loss: 0.5649 - val_accuracy: 0.7862
# Epoch 33/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4412 - accuracy: 0.8447 - val_loss: 0.5692 - val_accuracy: 0.7862
# Epoch 34/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4358 - accuracy: 0.8447 - val_loss: 0.5640 - val_accuracy: 0.7862
# Epoch 35/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4344 - accuracy: 0.8447 - val_loss: 0.5604 - val_accuracy: 0.7957
# Epoch 36/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4300 - accuracy: 0.8478 - val_loss: 0.5613 - val_accuracy: 0.7957
# Epoch 37/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4280 - accuracy: 0.8478 - val_loss: 0.5664 - val_accuracy: 0.7910
# Epoch 38/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4255 - accuracy: 0.8509 - val_loss: 0.5689 - val_accuracy: 0.7743
# Epoch 39/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4225 - accuracy: 0.8468 - val_loss: 0.5688 - val_accuracy: 0.7933
# Epoch 40/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4220 - accuracy: 0.8468 - val_loss: 0.5678 - val_accuracy: 0.7933
# Epoch 41/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4180 - accuracy: 0.8478 - val_loss: 0.5686 - val_accuracy: 0.7910
# Epoch 42/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4149 - accuracy: 0.8437 - val_loss: 0.5690 - val_accuracy: 0.7910
# Epoch 43/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4145 - accuracy: 0.8498 - val_loss: 0.5723 - val_accuracy: 0.7910
# Epoch 44/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4104 - accuracy: 0.8529 - val_loss: 0.5723 - val_accuracy: 0.7838
# Epoch 45/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4078 - accuracy: 0.8519 - val_loss: 0.5747 - val_accuracy: 0.7838
# Epoch 46/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4067 - accuracy: 0.8519 - val_loss: 0.5722 - val_accuracy: 0.7862
# Epoch 47/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4054 - accuracy: 0.8509 - val_loss: 0.5762 - val_accuracy: 0.7862
# Epoch 48/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4013 - accuracy: 0.8590 - val_loss: 0.5845 - val_accuracy: 0.7720
# Epoch 49/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4009 - accuracy: 0.8519 - val_loss: 0.5768 - val_accuracy: 0.7910
# Epoch 50/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8611 - val_loss: 0.5799 - val_accuracy: 0.7767
# Epoch 51/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3953 - accuracy: 0.8590 - val_loss: 0.5854 - val_accuracy: 0.7815
# Epoch 52/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3948 - accuracy: 0.8590 - val_loss: 0.5858 - val_accuracy: 0.7862
# Epoch 53/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3920 - accuracy: 0.8641 - val_loss: 0.5858 - val_accuracy: 0.7815
# Epoch 54/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3922 - accuracy: 0.8570 - val_loss: 0.5874 - val_accuracy: 0.7791
# Epoch 55/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3893 - accuracy: 0.8641 - val_loss: 0.5893 - val_accuracy: 0.7862
# Epoch 56/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3898 - accuracy: 0.8631 - val_loss: 0.5903 - val_accuracy: 0.7862
# Epoch 57/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8641 - val_loss: 0.5935 - val_accuracy: 0.7720
# Epoch 58/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3831 - accuracy: 0.8631 - val_loss: 0.5965 - val_accuracy: 0.7791
# Epoch 59/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3831 - accuracy: 0.8621 - val_loss: 0.5964 - val_accuracy: 0.7767
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5642 - accuracy: 0.7817
# Test Loss: 0.5642
# Test Accuracy: 0.7817

# %% [markdown]
# ❗ **The problem with strict Early Stopping** ❗
#
# The problem with this type of approach is that as soon as the loss of the validation set increases, the model stops. However, as a Neural Network's convergence is stochastic, the loss may slightly increase before decreasing again.
#
# ✅ The `EarlyStopping` criterion has a `patience` keyword that defines how many **consecutive epochs without any loss decrease** are allowed in the validation set before we stop the training procedure.
#
# Use the `EarlyStopping` criterion with a patience term of 30 epochs, plot the results, and print the accuracy on the testing set

# %%
# YOUR CODE HERE
es = EarlyStopping(patience=30, restore_best_weights=True)

model = initialize_model()

# Fit the model on the train data
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=500,
    batch_size=16,
    verbose=1,
    callbacks=[es]
)

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test, verbose=1)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 5ms/step - loss: 2.0713 - accuracy: 0.2278 - val_loss: 1.9678 - val_accuracy: 0.3420
# Epoch 2/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.8902 - accuracy: 0.4229 - val_loss: 1.7509 - val_accuracy: 0.4988
# Epoch 3/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.6589 - accuracy: 0.5046 - val_loss: 1.4951 - val_accuracy: 0.5843
# Epoch 4/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4188 - accuracy: 0.5557 - val_loss: 1.2786 - val_accuracy: 0.6081
# Epoch 5/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.2194 - accuracy: 0.6006 - val_loss: 1.1260 - val_accuracy: 0.6390
# Epoch 6/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.0619 - accuracy: 0.6517 - val_loss: 1.0015 - val_accuracy: 0.6770
# Epoch 7/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.9242 - accuracy: 0.7089 - val_loss: 0.8980 - val_accuracy: 0.7126
# Epoch 8/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8095 - accuracy: 0.7549 - val_loss: 0.8051 - val_accuracy: 0.7458
# Epoch 9/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7164 - accuracy: 0.7804 - val_loss: 0.7387 - val_accuracy: 0.7411
# Epoch 10/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6507 - accuracy: 0.8018 - val_loss: 0.6956 - val_accuracy: 0.7435
# Epoch 11/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6065 - accuracy: 0.8110 - val_loss: 0.6709 - val_accuracy: 0.7577
# Epoch 12/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5733 - accuracy: 0.8233 - val_loss: 0.6521 - val_accuracy: 0.7506
# Epoch 13/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5503 - accuracy: 0.8264 - val_loss: 0.6375 - val_accuracy: 0.7601
# Epoch 14/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5301 - accuracy: 0.8294 - val_loss: 0.6297 - val_accuracy: 0.7672
# Epoch 15/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5137 - accuracy: 0.8345 - val_loss: 0.6236 - val_accuracy: 0.7672
# Epoch 16/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5052 - accuracy: 0.8345 - val_loss: 0.6216 - val_accuracy: 0.7672
# Epoch 17/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4939 - accuracy: 0.8396 - val_loss: 0.6217 - val_accuracy: 0.7625
# Epoch 18/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4873 - accuracy: 0.8427 - val_loss: 0.6194 - val_accuracy: 0.7672
# Epoch 19/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4778 - accuracy: 0.8417 - val_loss: 0.6199 - val_accuracy: 0.7601
# Epoch 20/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4733 - accuracy: 0.8417 - val_loss: 0.6178 - val_accuracy: 0.7625
# Epoch 21/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4677 - accuracy: 0.8447 - val_loss: 0.6210 - val_accuracy: 0.7577
# Epoch 22/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4623 - accuracy: 0.8468 - val_loss: 0.6254 - val_accuracy: 0.7577
# Epoch 23/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4595 - accuracy: 0.8468 - val_loss: 0.6257 - val_accuracy: 0.7672
# Epoch 24/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4544 - accuracy: 0.8478 - val_loss: 0.6282 - val_accuracy: 0.7625
# Epoch 25/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4497 - accuracy: 0.8519 - val_loss: 0.6307 - val_accuracy: 0.7601
# Epoch 26/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4478 - accuracy: 0.8468 - val_loss: 0.6290 - val_accuracy: 0.7601
# Epoch 27/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4416 - accuracy: 0.8519 - val_loss: 0.6336 - val_accuracy: 0.7530
# Epoch 28/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4403 - accuracy: 0.8478 - val_loss: 0.6339 - val_accuracy: 0.7601
# Epoch 29/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4395 - accuracy: 0.8407 - val_loss: 0.6331 - val_accuracy: 0.7601
# Epoch 30/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4355 - accuracy: 0.8437 - val_loss: 0.6348 - val_accuracy: 0.7625
# Epoch 31/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4356 - accuracy: 0.8529 - val_loss: 0.6378 - val_accuracy: 0.7648
# Epoch 32/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4305 - accuracy: 0.8519 - val_loss: 0.6396 - val_accuracy: 0.7577
# Epoch 33/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4285 - accuracy: 0.8539 - val_loss: 0.6403 - val_accuracy: 0.7601
# Epoch 34/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4246 - accuracy: 0.8539 - val_loss: 0.6405 - val_accuracy: 0.7625
# Epoch 35/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4229 - accuracy: 0.8539 - val_loss: 0.6383 - val_accuracy: 0.7577
# Epoch 36/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4198 - accuracy: 0.8519 - val_loss: 0.6478 - val_accuracy: 0.7625
# Epoch 37/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4191 - accuracy: 0.8539 - val_loss: 0.6475 - val_accuracy: 0.7696
# Epoch 38/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4197 - accuracy: 0.8509 - val_loss: 0.6509 - val_accuracy: 0.7672
# Epoch 39/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4154 - accuracy: 0.8519 - val_loss: 0.6473 - val_accuracy: 0.7601
# Epoch 40/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4142 - accuracy: 0.8509 - val_loss: 0.6502 - val_accuracy: 0.7601
# Epoch 41/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4104 - accuracy: 0.8509 - val_loss: 0.6506 - val_accuracy: 0.7506
# Epoch 42/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4080 - accuracy: 0.8519 - val_loss: 0.6582 - val_accuracy: 0.7601
# Epoch 43/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8560 - val_loss: 0.6564 - val_accuracy: 0.7577
# Epoch 44/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8590 - val_loss: 0.6615 - val_accuracy: 0.7601
# Epoch 45/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4051 - accuracy: 0.8539 - val_loss: 0.6611 - val_accuracy: 0.7530
# Epoch 46/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4008 - accuracy: 0.8539 - val_loss: 0.6641 - val_accuracy: 0.7553
# Epoch 47/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3994 - accuracy: 0.8601 - val_loss: 0.6652 - val_accuracy: 0.7625
# Epoch 48/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8529 - val_loss: 0.6698 - val_accuracy: 0.7435
# Epoch 49/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3973 - accuracy: 0.8539 - val_loss: 0.6727 - val_accuracy: 0.7506
# Epoch 50/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3934 - accuracy: 0.8560 - val_loss: 0.6722 - val_accuracy: 0.7553
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5800 - accuracy: 0.7967
# Test Loss: 0.5800
# Test Accuracy: 0.7967

# %% [markdown]
# 🧑🏻‍🏫 **Remarks**
#
#
# - 📉 The model continues to converge even though its Loss Function had some consecutive loss increases/decreases w.r.t. to the number of epochs
# - 🤷🏻‍♂️ The `patience` number to select is highly related to the task at hand, and there is no general rule of thumb
# - 🧑🏻‍🏫 If you selected a high patience value for your Early Stopping:
#     - 🤞 your Neural Network should theoretically still stop training before the end (not always the case if your number of epochs is too low)
#     - ❗️ your validation loss will increase again after reaching a minimum value, but ideally, you want it to be as low as possible; the validation loss potentially reaches a minimum for certain weights at a certain epoch
#         - 🤔 How to find these weights?
#
# 📚 The `EarlyStopping` criterion enables you to:
# - stop the convergence
# - restore the best weights of the NN when it had the lowest error level (or the best score) on the validation set, thanks to `restore_best_weights = True` (set to `False` by default)

# %% [markdown]
# ##### Restoring the Best Weights of a Model
#
# - Run the model with an Early Stopping criterion that will restore the best weights of the Neural Net
# - Plot the loss and accuracy
# - Print the accuracy on the testing set

# %%
# YOUR CODE HERE
plot_loss_accuracy(history, title="Model Loss and Accuracy with Early Stopping")

# %% [markdown]
# 🥡 **Takeaways from the Early Stopping criterion:**
#
# - You can look at the 📚 [**Early Stopping documentation**](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping) to play with other parameters
# - You no longer need to have a look at the number of epochs as long as the model hits the stopping criterion. So, in the future, you should set a large number of epochs and the Early Stopping criterion will take care of stopping the training procedure before the model overfits!

# %% [markdown]
# ### (2.2) Batch Size & Epochs
#
# 🕵️‍♀️ Let's investigate the impact of the batch size on training a Neural Network and how we can use it to control how fast the parameters are updated.

# %% [markdown]
# #### Playing with the Batch Size
#
# Let's run the previous model with **different batch sizes** (with the Early Stopping criterion included) and plot the results.
#
# 👉 Run the following cell

# %%
# %%time
# RUN THIS CELL
es = EarlyStopping(patience=20, restore_best_weights=True)

for batch_size in [1, 4, 32]:

    model = initialize_model()

    history = model.fit(
        X_train_scaled,
        y_train,
        validation_split = 0.3,
        epochs = 500,
        batch_size = batch_size,
        verbose = 0,
        callbacks = [es]
    )

    results = model.evaluate(X_test_scaled, y_test, verbose=0)
    plot_loss_accuracy(history, title=f'------ BATCH SIZE {batch_size} ------\n The accuracy on the test set is of {results[1]:.2f}')
# Out:
# CPU times: user 1min 13s, sys: 31.7 s, total: 1min 45s
# Wall time: 1min 6s

# %% [markdown]
# #### ❓Question: Impact of the Batch Size on the Convergence of a Neural Network
#
# Look at the oscillations of the accuracy and the loss according to the batch size number.
#
# Is this coherent with what we saw when playing with the TensorFlow Playground?

# %% [markdown]
# > Smaller batch sizes tend to produce noisier updates to the model's weights, leading to more oscillations in the loss and accuracy curves. Larger batch sizes result in smoother convergence but may require more epochs to reach optimal performance.
#
# This behavior is consistent with observations from the TensorFlow Playground, where smaller batch sizes showed more frequent updates and oscillations, while larger batch sizes demonstrated steadier but slower convergence.

# %% [markdown]
# #### ❓Question: Number of Parameter Updates
#
# How many weight optimizations are done within one epoch (considering the number of observations and the batch size)? Does one epoch have more weight updates with a large or with a small batch size?

# %% [markdown]
# > Number of Parameter Updates<br>
# Smaller batch sizes result in more weight updates per epoch.<br>
# Larger batch sizes result in fewer weight updates per epoch but smoother convergence.

# %% [markdown]
# #### Explanations
#
# Copy and paste this code into a new cell, run it, and observe.
#
# ```python
# print(f"There are {X_train.shape[0]} rows in the training set")
#
# batch_size = 16
# epochs = 2
#
# model = initialize_model()
#
# history = model.fit(
#     X_train_scaled,
#     y_train,
#     validation_split = 0.3,
#     epochs = epochs,
#     batch_size = batch_size,
#     verbose = 1
# )
# ```
#
#
# <u><b>Number of parameter updates:</b></u>
#
# - There are 1400 rows in the training set:
#     - $ 70 \% \times 1400 = 980 $ rows are used as the training set within the training set
#     - $ 30 \% \times 1400 = 420 $ rows are used as the validation set
# - For each epoch, we run a forward/backward propagation $ \large \lceil \frac{980}{batch size} \rceil = \lceil \frac{980}{16}\rceil = 62$ times
# - Without the Early Stopping Criterion, we will have _number of_ $ epochs \times 62 = 2 \times 62 = 124 $ iterations overall
#
# <u><b>Impact of the batch size:</b></u>
#
# The smaller the batch size
#
# $ \implies $ The more sub-iterations will be done
# $ \implies $ Parameters will be updated more frequently
# $ \implies $ We may need fewer epochs
#
# _(but we also don't care too much about the number of epochs if we use an Early Stopping Criterion with a patience term anyway)_

# %%
batch_size = 16
epochs = 2

model = initialize_model()

history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = epochs,
    batch_size = batch_size,
    verbose = 1
)

# %% [markdown]
# ### (2.3) Regularization
#
# ❗️**Neural Networks with complex architectures can quickly lead to overfitting** (_too many layers and/or neurons_)❗️
#
# 🔥 But since Dense Neural Networks are just activated linear regressions, the weights can be constrained using L1, L2, or L1-L2 penalties!
#
# 🚓 So, let's apply some L2 or L1 penalties to these neurons; as in Machine Learning, these penalties are called **`Regularizers`**.
#
# 📚 <a href="https://www.tensorflow.org/api_docs/python/tf/keras/regularizers">See `tf.keras.regularizers`</a>

# %% [markdown]
# #### Observing Overfitting Before Regularizing
#
# First, let's initialize a model that has too many parameters for the task such that it overfits the training data quickly. To that purpose, let's not use any Early Stopping criterion.
#
# 🎁 Let's not waste time re-coding something that you are now used to, just run the following cell and observe what is happening 👇

# %%
# RUN THIS CELL

# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model Compilation
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 3. Training
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
    batch_size = 16,
    verbose=0
)

# 4. Evaluation
results_train = model.evaluate(X_train_scaled, y_train, verbose = 0)
results_test = model.evaluate(X_test_scaled, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the testing set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)

# %% [markdown]
# ☝️ In our "over-parameterized network", some neurons became **too specific for the given training data**, preventing the network from generalizing to new data.
#
# 😕 This led to some overfitting!

# %% [markdown]
# #### Studying the Impact of Regularization on the Neural Network
#
# Change the previous code to integrate an L2 or L1 regularizer into your Dense Layers.

# %%
# YOUR CODE HERE
from tensorflow.keras import regularizers

# YOUR CODE HERE
# Initialize a model with L2 regularization
model = models.Sequential()

# Input layer with L2 regularization
model.add(layers.Dense(25, activation='relu', input_dim=10, kernel_regularizer=regularizers.l2(0.01)))

# Hidden layer with L2 regularization
model.add(layers.Dense(10, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Predictive layer
model.add(layers.Dense(8, activation='softmax'))

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=100,
    batch_size=16,
    verbose=1
)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test, verbose=1)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/100
# 62/62 [==============================] - 0s 4ms/step - loss: 2.2007 - accuracy: 0.2635 - val_loss: 2.0578 - val_accuracy: 0.3017
# Epoch 2/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.9955 - accuracy: 0.3350 - val_loss: 1.8530 - val_accuracy: 0.4062
# Epoch 3/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.7787 - accuracy: 0.4780 - val_loss: 1.6477 - val_accuracy: 0.5439
# Epoch 4/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.5682 - accuracy: 0.5914 - val_loss: 1.4504 - val_accuracy: 0.6176
# Epoch 5/100
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3765 - accuracy: 0.6680 - val_loss: 1.2813 - val_accuracy: 0.7007
# Epoch 6/100
# 62/62 [==============================] - 0s 2ms/step - loss: 1.2141 - accuracy: 0.7314 - val_loss: 1.1501 - val_accuracy: 0.7482
# Epoch 7/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.0942 - accuracy: 0.7681 - val_loss: 1.0602 - val_accuracy: 0.7625
# Epoch 8/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.0056 - accuracy: 0.7886 - val_loss: 0.9983 - val_accuracy: 0.7720
# Epoch 9/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.9464 - accuracy: 0.7835 - val_loss: 0.9599 - val_accuracy: 0.7696
# Epoch 10/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.9071 - accuracy: 0.7988 - val_loss: 0.9366 - val_accuracy: 0.7601
# Epoch 11/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8782 - accuracy: 0.8069 - val_loss: 0.9249 - val_accuracy: 0.7601
# Epoch 12/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8552 - accuracy: 0.8059 - val_loss: 0.9051 - val_accuracy: 0.7672
# Epoch 13/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8391 - accuracy: 0.8069 - val_loss: 0.8924 - val_accuracy: 0.7672
# Epoch 14/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8278 - accuracy: 0.8172 - val_loss: 0.8893 - val_accuracy: 0.7743
# Epoch 15/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8119 - accuracy: 0.8161 - val_loss: 0.8787 - val_accuracy: 0.7743
# Epoch 16/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7987 - accuracy: 0.8274 - val_loss: 0.8704 - val_accuracy: 0.7767
# Epoch 17/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7904 - accuracy: 0.8264 - val_loss: 0.8641 - val_accuracy: 0.7815
# Epoch 18/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7795 - accuracy: 0.8335 - val_loss: 0.8572 - val_accuracy: 0.7743
# Epoch 19/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7696 - accuracy: 0.8345 - val_loss: 0.8545 - val_accuracy: 0.7743
# Epoch 20/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7640 - accuracy: 0.8366 - val_loss: 0.8469 - val_accuracy: 0.7696
# Epoch 21/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7566 - accuracy: 0.8304 - val_loss: 0.8425 - val_accuracy: 0.7791
# Epoch 22/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7505 - accuracy: 0.8345 - val_loss: 0.8392 - val_accuracy: 0.7815
# Epoch 23/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7449 - accuracy: 0.8366 - val_loss: 0.8284 - val_accuracy: 0.7838
# Epoch 24/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7390 - accuracy: 0.8345 - val_loss: 0.8249 - val_accuracy: 0.7648
# Epoch 25/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7360 - accuracy: 0.8335 - val_loss: 0.8201 - val_accuracy: 0.7743
# Epoch 26/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7293 - accuracy: 0.8386 - val_loss: 0.8189 - val_accuracy: 0.7743
# Epoch 27/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7230 - accuracy: 0.8376 - val_loss: 0.8121 - val_accuracy: 0.7791
# Epoch 28/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7195 - accuracy: 0.8335 - val_loss: 0.8064 - val_accuracy: 0.7767
# Epoch 29/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7170 - accuracy: 0.8345 - val_loss: 0.8060 - val_accuracy: 0.7791
# Epoch 30/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7122 - accuracy: 0.8407 - val_loss: 0.7979 - val_accuracy: 0.7862
# Epoch 31/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7083 - accuracy: 0.8304 - val_loss: 0.7969 - val_accuracy: 0.7815
# Epoch 32/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.
100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6088 - accuracy: 0.8509 - val_loss: 0.7257 - val_accuracy: 0.7957
# Epoch 96/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6092 - accuracy: 0.8498 - val_loss: 0.7198 - val_accuracy: 0.7933
# Epoch 97/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6059 - accuracy: 0.8488 - val_loss: 0.7263 - val_accuracy: 0.7910
# Epoch 98/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6068 - accuracy: 0.8447 - val_loss: 0.7255 - val_accuracy: 0.7791
# Epoch 99/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6051 - accuracy: 0.8427 - val_loss: 0.7253 - val_accuracy: 0.7886
# Epoch 100/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6047 - accuracy: 0.8478 - val_loss: 0.7204 - val_accuracy: 0.7957
# 19/19 [==============================] - 0s 1ms/step - loss: 0.7148 - accuracy: 0.7850
# Test Loss: 0.7148
# Test Accuracy: 0.7850

# %% [markdown]
# ### (2.4) Dropout Layers

# %% [markdown]
# #### Introduction to Dropout Layers
#
# The role of a Dropout Layer is to randomly cancel the output of some neurons during the training phase, it prevents the network from getting too specific for the input data.
#
# Dropout Layers
# - ensure that no neuron can overspecialize in learning a pattern of the dataset because its output is sometimes canceled
# - force the information of an input to be spread across multiple neurons instead of only one specific neuron
# - are super straightforward to code 👌
#   - but what is going on _under the hood_? 👩🏻‍🏫

# %% [markdown]
# #### Optional Reading
#
# <details>
#     <summary>Click here for further explanations about Dropout Layers</summary>
#
# 🤔 Remember what we said about neurons becoming **too specific**?
#
# **`BEGIN_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
#
# ---
#
# ⚽️  **A Football Analogy:**
#
# Think about a football team. There are 11 players on the pitch, but there are also players on the bench. Why?
# - The coach may want to substitute injured or tired players during the game
# - The team may be
#     - losing the game and willing to substitute a midfielder with a more **versatile player** who can be more offensive (= **mix of** midfielder/attacker roles)
#     - winning the game and would like to secure the result by replacing a midfielder with a more **versatile player** who can be more defensive (= **mix of** midfielder/defense roles)
#
# 💡 Well, in a Neural Net, there is also a risk that a neuron over-specializes in detecting one pattern, where it would be advisable to keep it more versatile.
#
# ---
#
# 📚 **The goal of [Dropout Layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) is to prevent neurons from over-specializing.**
#
# 🧑🏻‍🏫 How do Dropout Layers work?
#
# 👉 When we apply a **Dropout rate** of 20% to a layer $k$, 20% of the **selected neurons** will have their weights **temporarily set to 0** , which has the following consequences:
# 1. A neuron computed at layer $k + 1$ considers all the weights as usual, but since some of them were temporarily set to 0, they were “ignored” while creating the neurons of this layer $k + 1$
# 2. Once a batch of data points has been seen by the Neural Network (**forward propagation**) and 80% of the weights in a layer have been optimized/updated (**backward propagation** with the **Adam** optimizer), the Neural Network moves on to the forward propagation of the next batch, where it will use:
#    - 80% of the weights; the ones that were updated
#    - 20% of the weights; the ones that were previously ignored and had their values **temporarily** set to 0
#
# Based on these weights, we will go through this Dropout Layer again, which is going to temporarily ignore another 20% of the weights of a given layer. Be careful, the selection of this 20% is random, so the weights that will be ignored this time won't necessarily be the same as before!
#
# 👉 Think about the **Dropout rate** as a **sampling with replacement**
#
# 👉 By **randomly shutting down** different neurons at different epochs, we force the data points to be **analyzed by different neurons**. At the end of the day, these neurons will become **more versatile** instead of over-specializing!
#
# ---
#
# **`END_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
# </details>

# %% [markdown]
# #### Studying the Impact of Dropout Layers on the Neural Network
#
# Include some Dropout layers in the architecture of your original model _(don't add regularizers here)_.
#
# What can you observe regarding the convergence of your model? What about its ability to generalize?

# %%
# YOUR CODE HERE
# Adding Dropout layers to the model
model = models.Sequential()

# Input layer with Dropout
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dropout(0.2))  # Dropout rate of 20%

# Hidden layer with Dropout
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dropout(0.2))  # Dropout rate of 20%

# Predictive layer
model.add(layers.Dense(8, activation='softmax'))

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=100,
    batch_size=16,
    verbose=1
)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test, verbose=1)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/100
# 62/62 [==============================] - 1s 4ms/step - loss: 2.0691 - accuracy: 0.1696 - val_loss: 1.9273 - val_accuracy: 0.2660
# Epoch 2/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.8989 - accuracy: 0.2880 - val_loss: 1.7434 - val_accuracy: 0.4442
# Epoch 3/100
# 62/62 [==============================] - 0s 2ms/step - loss: 1.7172 - accuracy: 0.3830 - val_loss: 1.5517 - val_accuracy: 0.5606
# Epoch 4/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.5678 - accuracy: 0.4423 - val_loss: 1.3809 - val_accuracy: 0.6461
# Epoch 5/100
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4274 - accuracy: 0.5128 - val_loss: 1.2201 - val_accuracy: 0.6888
# Epoch 6/100
# 62/62 [==============================] - 0s 2ms/step - loss: 1.2947 - accuracy: 0.5812 - val_loss: 1.0788 - val_accuracy: 0.7268
# Epoch 7/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.2179 - accuracy: 0.5679 - val_loss: 0.9562 - val_accuracy: 0.7577
# Epoch 8/100
# 62/62 [==============================] - 0s 2ms/step - loss: 1.1176 - accuracy: 0.6037 - val_loss: 0.8661 - val_accuracy: 0.7720
# Epoch 9/100
# 62/62 [==============================] - 0s 2ms/step - loss: 1.0790 - accuracy: 0.6170 - val_loss: 0.8017 - val_accuracy: 0.7767
# Epoch 10/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.0896 - accuracy: 0.6057 - val_loss: 0.7611 - val_accuracy: 0.7815
# Epoch 11/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.0038 - accuracy: 0.6353 - val_loss: 0.7259 - val_accuracy: 0.7767
# Epoch 12/100
# 62/62 [==============================] - 0s 2ms/step - loss: 1.0239 - accuracy: 0.6118 - val_loss: 0.7067 - val_accuracy: 0.7743
# Epoch 13/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9705 - accuracy: 0.6353 - val_loss: 0.6868 - val_accuracy: 0.7815
# Epoch 14/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9698 - accuracy: 0.6415 - val_loss: 0.6721 - val_accuracy: 0.7838
# Epoch 15/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9546 - accuracy: 0.6323 - val_loss: 0.6601 - val_accuracy: 0.7791
# Epoch 16/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9277 - accuracy: 0.6547 - val_loss: 0.6536 - val_accuracy: 0.7791
# Epoch 17/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9529 - accuracy: 0.6404 - val_loss: 0.6463 - val_accuracy: 0.7862
# Epoch 18/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9434 - accuracy: 0.6486 - val_loss: 0.6458 - val_accuracy: 0.7791
# Epoch 19/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9311 - accuracy: 0.6537 - val_loss: 0.6370 - val_accuracy: 0.7838
# Epoch 20/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9234 - accuracy: 0.6568 - val_loss: 0.6333 - val_accuracy: 0.7886
# Epoch 21/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9253 - accuracy: 0.6639 - val_loss: 0.6294 - val_accuracy: 0.7933
# Epoch 22/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8909 - accuracy: 0.6721 - val_loss: 0.6214 - val_accuracy: 0.7791
# Epoch 23/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8722 - accuracy: 0.6599 - val_loss: 0.6159 - val_accuracy: 0.7743
# Epoch 24/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8864 - accuracy: 0.6456 - val_loss: 0.6146 - val_accuracy: 0.7815
# Epoch 25/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9038 - accuracy: 0.6660 - val_loss: 0.6133 - val_accuracy: 0.7767
# Epoch 26/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8837 - accuracy: 0.6547 - val_loss: 0.6098 - val_accuracy: 0.7767
# Epoch 27/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8677 - accuracy: 0.6834 - val_loss: 0.6029 - val_accuracy: 0.7743
# Epoch 28/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8786 - accuracy: 0.6762 - val_loss: 0.6057 - val_accuracy: 0.7743
# Epoch 29/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8438 - accuracy: 0.6905 - val_loss: 0.6078 - val_accuracy: 0.7743
# Epoch 30/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8352 - accuracy: 0.6874 - val_loss: 0.6033 - val_accuracy: 0.7743
# Epoch 31/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8488 - accuracy: 0.6711 - val_loss: 0.6055 - val_accuracy: 0.7720
# Epoch 32/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8327 - accuracy: 0.6987 - val_loss: 0.6036 - val_accuracy: 0.7767
# Epoch 33/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8571 - accuracy: 0.6885 - val_loss: 0.6060 - val_accuracy: 0.7743
# Epoch 34/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8531 - accuracy: 0.6772 - val_loss: 0.6055 - val_accuracy: 0.7767
# Epoch 35/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8744 - accuracy: 0.6588 - val_loss: 0.6115 - val_accuracy: 0.7767
# Epoch 36/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8191 - accuracy: 0.6813 - val_loss: 0.6059 - val_accuracy: 0.7767
# Epoch 37/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7973 - accuracy: 0.7048 - val_loss: 0.5977 - val_accuracy: 0.7838
# Epoch 38/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8516 - accuracy: 0.6956 - val_loss: 0.6018 - val_accuracy: 0.7743
# Epoch 39/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8628 - accuracy: 0.6691 - val_loss: 0.5994 - val_accuracy: 0.7815
# Epoch 40/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8039 - accuracy: 0.6925 - val_loss: 0.5990 - val_accuracy: 0.7815
# Epoch 41/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8254 - accuracy: 0.6905 - val_loss: 0.5984 - val_accuracy: 0.7862
# Epoch 42/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8107 - accuracy: 0.7048 - val_loss: 0.5924 - val_accuracy: 0.7886
# Epoch 43/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7937 - accuracy: 0.7211 - val_loss: 0.5922 - val_accuracy: 0.7886
# Epoch 44/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8222 - accuracy: 0.6956 - val_loss: 0.5883 - val_accuracy: 0.7838
# Epoch 45/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7647 - accuracy: 0.7181 - val_loss: 0.5852 - val_accuracy: 0.7886
# Epoch 46/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7662 - accuracy: 0.7222 - val_loss: 0.5863 - val_accuracy: 0.7720
# Epoch 47/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7507 - accuracy: 0.7140 - val_loss: 0.5820 - val_accuracy: 0.7767
# Epoch 48/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7630 - accuracy: 0.7079 - val_loss: 0.5827 - val_accuracy: 0.7886
# Epoch 49/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8190 - accuracy: 0.6915 - val_loss: 0.5872 - val_accuracy: 0.7862
# Epoch 50/100
# 62/62 [==============================] - 1s 14ms/step - loss: 0.7899 - accuracy: 0.7048 - val_loss: 0.5879 - val_accuracy: 0.7838
# Epoch 51/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8089 - accuracy: 0.6977 - val_loss: 0.5865 - val_accuracy: 0.7910
# Epoch 52/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7905 - accuracy: 0.7130 - val_loss: 0.5853 - val_accuracy: 0.7886
# Epoch 53/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7980 - accuracy: 0.7079 - val_loss: 0.5860 - val_accuracy: 0.7886
# Epoch 54/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8017 - accuracy: 0.7079 - val_loss: 0.5791 - val_accuracy: 0.7886
# Epoch 55/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7823 - accuracy: 0.7099 - val_loss: 0.5800 - val_accuracy: 0.7933
# Epoch 56/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7566 - accuracy: 0.7222 - val_loss: 0.5751 - val_accuracy: 0.7957
# Epoch 57/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8019 - accuracy: 0.7109 - val_loss: 0.5730 - val_accuracy: 0.7957
# Epoch 58/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7915 - accuracy: 0.7344 - val_loss: 0.5788 - val_accuracy: 0.7886
# Epoch 59/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7586 - accuracy: 0.7273 - val_loss: 0.5807 - val_accuracy: 0.7886
# Epoch 60/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8144 - accuracy: 0.6966 - val_loss: 0.5849 - val_accuracy: 0.7791
# Epoch 61/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7424 - accuracy: 0.7171 - val_loss: 0.5872 - val_accuracy: 0.7910
# Epoch 62/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7675 - accuracy: 0.7252 - val_loss: 0.5799 - val_accuracy: 0.7862
# Epoch 63/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7647 - accuracy: 0.7263 - val_loss: 0.5788 - val_accuracy: 0.7933
# Epoch 64/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7965 - accuracy: 0.7099 - val_loss: 0.5786 - val_accuracy: 0.7886
# Epoch 65/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7704 - accuracy: 0.7191 - val_loss: 0.5828 - val_accuracy: 0.7886
# Epoch 66/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7548 - accuracy: 0.7273 - val_loss: 0.5824 - val_accuracy: 0.7862
# Epoch 67/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7505 - accuracy: 0.7242 - val_loss: 0.5809 - val_accuracy: 0.7815
# Epoch 68/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7455 - accuracy: 0.7283 - val_loss: 0.5772 - val_accuracy: 0.7886
# Epoch 69/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7199 - accuracy: 0.7344 - val_loss: 0.5765 - val_accuracy: 0.7886
# Epoch 70/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8040 - accuracy: 0.6895 - val_loss: 0.5766 - val_accuracy: 0.7886
# Epoch 71/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7465 - accuracy: 0.7242 - val_loss: 0.5840 - val_accuracy: 0.7862
# Epoch 72/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7755 - accuracy: 0.7150 - val_loss: 0.5818 - val_accuracy: 0.7886
# Epoch 73/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7286 - accuracy: 0.7252 - val_loss: 0.5760 - val_accuracy: 0.7910
# Epoch 74/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7484 - accuracy: 0.7406 - val_loss: 0.5773 - val_accuracy: 0.7886
# Epoch 75/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7088 - accuracy: 0.7385 - val_loss: 0.5773 - val_accuracy: 0.7933
# Epoch 76/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7227 - accuracy: 0.7426 - val_loss: 0.5790 - val_accuracy: 0.7838
# Epoch 77/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7489 - accuracy: 0.7365 - val_loss: 0.5764 - val_accuracy: 0.7838
# Epoch 78/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7561 - accuracy: 0.7457 - val_loss: 0.5797 - val_accuracy: 0.7862
# Epoch 79/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7462 - accuracy: 0.7477 - val_loss: 0.5781 - val_accuracy: 0.7910
# Epoch 80/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7196 - accuracy: 0.7589 - val_loss: 0.5752 - val_accuracy: 0.7886
# Epoch 81/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6997 - accuracy: 0.7497 - val_loss: 0.5735 - val_accuracy: 0.7910
# Epoch 82/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7104 - accuracy: 0.7528 - val_loss: 0.5748 - val_accuracy: 0.7886
# Epoch 83/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7163 - accuracy: 0.7283 - val_loss: 0.5767 - val_accuracy: 0.7862
# Epoch 84/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7261 - accuracy: 0.7436 - val_loss: 0.5788 - val_accuracy: 0.7767
# Epoch 85/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7277 - accuracy: 0.7314 - val_loss: 0.5792 - val_accuracy: 0.7862
# Epoch 86/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7053 - accuracy: 0.7467 - val_loss: 0.5772 - val_accuracy: 0.7791
# Epoch 87/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7003 - accuracy: 0.7508 - val_loss: 0.5784 - val_accuracy: 0.7815
# Epoch 88/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7605 - accuracy: 0.7242 - val_loss: 0.5793 - val_accuracy: 0.7815
# Epoch 89/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7283 - accuracy: 0.7416 - val_loss: 0.5763 - val_accuracy: 0.7838
# Epoch 90/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7511 - accuracy: 0.7344 - val_loss: 0.5779 - val_accuracy: 0.7862
# Epoch 91/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7397 - accuracy: 0.7303 - val_loss: 0.5744 - val_accuracy: 0.7838
# Epoch 92/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.7640 - val_loss: 0.5742 - val_accuracy: 0.7815
# Epoch 93/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6998 - accuracy: 0.7477 - val_loss: 0.5701 - val_accuracy: 0.7886
# Epoch 94/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6680 - accuracy: 0.7549 - val_loss: 0.5763 - val_accuracy: 0.7838
# Epoch 95/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7319 - accuracy: 0.7120 - val_loss: 0.5779 - val_accuracy: 0.7838
# Epoch 96/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6976 - accuracy: 0.7579 - val_loss: 0.5756 - val_accuracy: 0.7838
# Epoch 97/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6835 - accuracy: 0.7477 - val_loss: 0.5775 - val_accuracy: 0.7815
# Epoch 98/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7158 - accuracy: 0.7365 - val_loss: 0.5736 - val_accuracy: 0.7838
# Epoch 99/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6568 - accuracy: 0.7528 - val_loss: 0.5730 - val_accuracy: 0.7862
# Epoch 100/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.7446 - val_loss: 0.5771 - val_accuracy: 0.7815
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5996 - accuracy: 0.7767
# Test Loss: 0.5996
# Test Accuracy: 0.7767

# %% [markdown]
# ## (3) Conclusions
#
# - ❗️ If you train a Neural Network too much (too many layers, too many neurons, and/or too many epochs), it will overfit very quickly
# - 🥊 To prevent overfitting in Deep Learning, you can use Early Stopping, Regularization, and Dropout Layers
# - ❗️ Be careful, if you use these techniques, you might end up on the other spectrum of the performance where your model would underfit the dataset!
# - 🆗 You could potentially look at the batch size but we usually use 16 or 32; and as the French Computer Scientist [**Yann Lecun**](https://en.wikipedia.org/wiki/Yann_LeCun) said (Facebook x NYU):
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/deep_learning_yann_lecun_batch_size.png" alt="batch_size_yann_lecun" width="500">

# %% [markdown]
# ## 🏁 Congratulations!
#
# 💾 Do not forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move to the next challenge!
